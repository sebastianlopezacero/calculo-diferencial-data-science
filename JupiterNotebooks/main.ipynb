# %% [markdown]
# # Librerias

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Límites

# %% [markdown]
# ## ¿Qué es un límite?

# %% [markdown]
# Un límite es un análisis de tendencia respecto a un punto. Es decir, hacia donde va el valor de nuestra función a medida que “x” se acerca al valor “a”, pero sin tocar nunca ese valor “a”. Por eso se llama límite, porque “tenemos prohibido tocar” ese valor “a”.
#
# $$ \lim_{{x \to a}} f(x) = L $$
#
# Una analogía para entender el límite es la siguiente: supón que tienes una fogata encendida frente a tí, y quieres comprobar que el fuego que estás viendo existe, que tus ojos no te engañan. Para ello, acercas las manos al fuego, cada vez más despacio, a ver si las sientes más calientes, pero nunca llegas a estar directamente en el fuego porque te puedes quemar.

# %% [markdown]
# ## Resolución de límites e interpretación

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <b style="font-size: 1.5em;"> 🤔 Essential detail</b>
#     <p>
#         Los limites <b>NO</b> son evaluar funciones, sino saber que pasa con la función cuando se aproxima a cierto valor
#     </p>
# </div>

# %% [markdown]
# Para resolver un límite veamos el concepto de límites laterales. Un límite lateral es cuando nos acercamos a un valor por un lado, ya sea por la izquierda o la derecha. Los límites laterales se denotan de la siguiente manera.
#
# $$ \lim_{{x \to a^+}} f(x) = L $$
#
# Esto es un límite lateral a la izquierda. Un límite lateral a la derecha se denota del mismo modo, excepto que elevamos la constante “a” al signo positivo.
#
# $$ \lim_{{x \to a^-}} f(x) = L $$
#
#
# Los límites laterales son importantes, ya que para que el límite en general exista, los dos límites laterales deben ser iguales.

# %% [markdown]
# # Derivada en ciencia de datos

# %% [markdown]
# ## Definición de la derivada

# %% [markdown]
# El problema de la derivada nace de tratar de encontrar la recta tangente a un punto en una curva. La primera solución (por parte de Isaac Newton) fué tomar una recta secante, es decir una recta que corta a la curva en dos puntos.

# %% [markdown]
# De la imagen anterior nos damos cuenta que estos dos puntos están dados por
#
# $$ {P_{1}} = (x,f(x)) $$
#
# y
#
# $$ {P_{2}} = ((x+h),f(x+h)) $$
#
# donde “h” es la distancia horizontal entre dichos puntos. Mediante estos dos puntos, podemos calcular la pendiente de la recta secante con la fórmula
#
# $$ m = \frac{y_{2}-y_{1}}{x_{2}-x_{1}} $$
#
# donde m es la pendiente.
#
# Sin embargo, esto nos da la pendiente de la recta secante. Queremos encontrar la de la recta tangente. Para ello, debemos recortar la distancia “h”, hasta que sea muy cercana a cero.
#
# Entonces tomamos el límite, y esto nos da la pendiente de la recta tangente en un punto x de la curva. A este límite es lo que llamamos derivada.
#
# $$ \lim_{{h \to 0}} = \frac{f(x+h)-f(x)}{h}  $$
#
# La derivada también se puede ver en términos de incrementos. El numerador sería el incremento $\delta{y}$ entre las funciones o también el valor de y, mientras que el denominador sería el incremento $\delta{x}$ entre los valores de x.

# %% [markdown]
# ## La derivada como razón de cambio

# %% [markdown]
# Supón que llevas un tiempo estudiando la relación entre los años de experiencia como desarrollador de software (developer) y el salario de este trabajo. Llegas a la conclusión de que esta relación es cuadrática, y que el gráfico se ve como una parábola. Llamemos “s” al salario y “a” a la cantidad de años de experiencia. La relación entre ambas variables sería $s(a)=a^2$
#
# Si quisieras saber que tanto sube el salario en función de los años, podemos calcular la derivada. Esta nos va a decir que tan rápido cambia “s” respecto a “a”. La derivada de una función cuadrática $f(x)=x^2$  es simplemente $f´(x)=x^2$ , por lo que en este caso nos queda $s´(a)=a^2$
#
#  En general, la derivada de una función $f(x)=x^n$ es $f´(x)=nx^{n-1}$. Aquí puedes ver una tabla de drivadas comunes.

# %% [markdown]
# ## Implementación de la derivada discreta

# %%
# Función inicial f(x)
def f(x):
    return x**2

x = np.linspace(-10,10,num=1000)
y = f(x)

# Calculando la deriva de la función
def df(f):
    h = 0.0000000000001
    return (f(x+h)-f(x))/h
# Graficando la función
plt.plot(x,y, "b")
plt.plot(x,df(f),"r--", label="Derivada 1")
plt.legend()
plt.grid()

# %% [markdown]
# # Introducción a máximos y mínimos

# %% [markdown]
# ## ¿Qué es un máximo y un mínimo?

# %% [markdown]
# En matemáticas, un máximo y un mínimo son valores extremos de una función que representan los puntos más altos y más bajos, respectivamente. Estos extremos son importantes en el análisis de funciones, ya que brindan información sobre los puntos críticos y las características de la función. A continuación, se describen con más detalle cada uno de ellos:
#
# - *Máximo:*
# Un máximo de una función es el valor más alto que la función alcanza en un determinado intervalo o en todo su dominio. Formalmente, sea f una función definida en un conjunto D, se dice que f tiene un máximo en el punto c si $f(c)$ es mayor o igual que $f(x)$ para todo x en D cercano a c. Un máximo absoluto es aquel que es el valor más alto de la función en todo su dominio, mientras que un máximo relativo es aquel que es el valor más alto en un intervalo específico.
# - *Mínimo:*
# Un mínimo de una función es el valor más bajo que la función alcanza en un determinado intervalo o en todo su dominio. Formalmente, sea f una función definida en un conjunto D, se dice que f tiene un mínimo en el punto c si $f(c)$ es menor o igual que $f(x)$ para todo x en D cercano a c. Un mínimo absoluto es aquel que es el valor más bajo de la función en todo su dominio, mientras que un mínimo relativo es aquel que es el valor más bajo en un intervalo específico.

# %% [markdown]
# # Derivadas de funciones de activación

# %%
def df(f):
    h = 0.000001
    return (f(x+h)-f(x))/h

# %% [markdown]
# ### Función lineal

# %% [markdown]
# $$ f(x) = mx+b$$
# $$ f´(x) = m$$

# %%
def f(x):
    return x

plt.plot(x, f(x),"b")
plt.plot(x,df(f),"r")
plt.grid()

# %% [markdown]
# ### Función escalón o de Heaviside

# %% [markdown]
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$
#
# Derivada
#
# $$f´(x)=0$$

# %%
def H(x):
  Y = np.zeros(len(x))
  for idx,x in enumerate(x):
    if x>=0:
      Y[idx]=1
  return Y
    
N=1000


y = H(x)

plt.plot(x, H(x), 'b')
plt.plot(x,df(H), 'r')
plt.grid()

# %% [markdown]
# ### Función sigmoide

# %% [markdown]
# ## Función sigmoide
#
# $$f(x)=\frac{1}{1-e^{-x}}$$
#
# Derivada
#
# $$f´(x)=f(x)(1-f(x))$$

# %%
def f(x):
  return 1/(1 + np.exp(-x))
    

N=1000

y = f(x)

plt.plot(x, f(x), 'b')
plt.plot(x,df(f), 'r')
plt.grid()

# %% [markdown]
# ### Función hiperbólica

# %% [markdown]
# ## Función tangente hiperbólica
#
# $$f(x)=\frac{2}{1+e^{-2x}}-1$$
#
# Derivada
#
# $$f´(x)=1-f(x)^2$$

# %%
def f(x):
  return np.tanh(x)
    

N=1000

y = f(x)

plt.plot(x, f(x), 'b')
plt.plot(x,df(f), 'r')
plt.grid()

# %% [markdown]
# ## Función ReLu

# %% [markdown]
# ## Función ReLU
#
# $$R(x)=max(0,x)$$
#  También se puede escribir como
# $$R(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         x,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$
#
# Derivada
#
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$

# %%
def f(x):
  return np.maximum(x,0)
    

N=1000

y = f(x)

plt.plot(x, f(x), 'b')
plt.plot(x,df(f), 'r')
plt.grid()
